// %% [markdown]
// # Control Flow and Arrays in C++
//
// Use this notebook to practice conditions, loops, arrays, and vectors with the C++17 kernel.

// %% [markdown]
// ## 1. If Else

// %%
#include <iostream>
using namespace std;

int marks = 78;

if (marks >= 90) {
    cout << "Grade A" << endl;
} else if (marks >= 75) {
    cout << "Grade B" << endl;
} else if (marks >= 40) {
    cout << "Grade C" << endl;
} else {
    cout << "Fail" << endl;
}

// %% [markdown]
// ## 2. For Loop

// %%
for (int i = 1; i <= 10; i++) {
    cout << i << " ";
}
cout << endl;

// %% [markdown]
// ## 3. Array

// %%
int arr[5] = {10, 20, 30, 40, 50};
int total = 0;

for (int i = 0; i < 5; i++) {
    total += arr[i];
}

cout << "Total = " << total << endl;
cout << "Average = " << total / 5.0 << endl;

// %% [markdown]
// ## 4. Vector

// %%
#include <vector>

vector<int> scores = {82, 90, 76, 88};
int sum = 0;

for (int score : scores) {
    sum += score;
}

cout << "Average score = " << sum / static_cast<double>(scores.size()) << endl;

// %% [markdown]
// ## Practice
//
// - Print the multiplication table of a number.
// - Find the maximum value in an array.
// - Count how many scores are greater than or equal to 75.

// %% [markdown]
// ## 5. Intensive: Array Statistics
//
// This cell computes total, average, highest, lowest, pass count, and fail count from one array.

// %%
int marksList[6] = {82, 91, 61, 48, 76, 35};
int count = 6;
int totalMarks = 0;
int highest = marksList[0];
int lowest = marksList[0];
int passCount = 0;

for (int i = 0; i < count; i++) {
    totalMarks += marksList[i];
    if (marksList[i] > highest) highest = marksList[i];
    if (marksList[i] < lowest) lowest = marksList[i];
    if (marksList[i] >= 40) passCount++;
}

cout << "Average = " << totalMarks / static_cast<double>(count) << endl;
cout << "Highest = " << highest << endl;
cout << "Lowest = " << lowest << endl;
cout << "Pass count = " << passCount << endl;
cout << "Fail count = " << count - passCount << endl;

// %% [markdown]
// ## 6. Intensive: Structures for Records

// %%
#include <string>

struct Student {
    string name;
    int roll;
    double marks;
};

Student s1 = {"Asha", 101, 88.5};
cout << s1.roll << " " << s1.name << " " << s1.marks << endl;

// %% [markdown]
// ## 7. Intensive Practice
//
// 1. Add three more students using an array or vector of structures.
// 2. Print a multiplication table using nested loops.
// 3. Write a grade calculator with invalid-marks checking.
// 4. Print square, triangle, and inverted triangle star patterns.
// 5. Explain why arrays use index `0` for the first element.
